# %%
l1 = [0,1,2,3,5,0,1,2,3,5]
l2 = [4,5,6,7,0,0,1,5]
vis= [0]*len(l2)

a = []
for i in range(len(l1)):
    for j in range(len(l2)):
        if (l1[i] == l2[j]) and vis[j] == 0:
            a.append(l1[i])
            vis[j] = 1
a
# Out:
# [0, 0, 1, 5, 5]

# %%
l = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']

d= {}
for i in l:
    if i not in d:
        d[i]= 1
    
    else:
        d[i] += 1

# %%
d
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}
